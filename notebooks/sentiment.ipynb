# %%
import pandas as pd
from string import punctuation
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
import unidecode
from gensim import corpora
import gensim

import nltk
stemmer = nltk.stem.SnowballStemmer('portuguese')

#login = 108561

#archackathon.database.windows.net
#AcrConsultada
#Arc123456

# %% [markdown]
# ### Lendo os dados

# %%
ranking_complete = pd.read_csv('data/ranking_complete.csv', encoding='latin-1')
ranking_complete = ranking_complete[ranking_complete['Pages'] > 2]

# %%
ranking_complete.head()
# Out:
#    Conforto / Acabamento  Consumo  Custo / Benefício  Design  Dirigibilidade  \
# 5                    3.0      9.0                9.0     3.0             7.0
# 6                    5.8      8.2                7.3     6.8             7.3
# 7                    9.0      9.0                9.5    10.0            10.0
# 8                    5.0      0.0                5.0    10.0             7.0
# 9                    6.5      8.5                9.0     6.2             9.0
#
#    Manutenção  Performance       Marca      Modelo   Ano  Pages  \
# 5         8.0          7.0        FIAT  UNO FURGÃO  2016      3
# 6         7.8          7.2  VOLKSWAGEN    BRASÍLIA  1981      5
# 7         9.0         10.0  VOLKSWAGEN       FUSCA  2016      7
# 8         8.0          7.0        FIAT     FIORINO  2019      4
# 9         9.5          9.2        FORD     COURIER  2013      5
#
#                                       Texto Positivo     Price  ranking  \
# 5  \r\r\nPontos positivos: responde bem ao que se...   30252.0      NaN
# 6  \r\r\nPontos positivos: todo bom\r\r\r\n      ...   17800.0      NaN
# 7  \r\r\nPontos positivos: confiança no uso diári...  107352.0      NaN
# 8  \r\r\nPontos positivos: bom carro para trabalh...   60070.0      NaN
# 9  \r\r\nPontos positivos: resist?ncia e performa...   24940.0      NaN
#
#    Value  vendas_normalizada
# 5    0.0                 0.0
# 6    0.0                 0.0
# 7    0.0                 0.0
# 8    0.0                 0.0
# 9    0.0                 0.0

# %% [markdown]
# ### Limpando os textos

# %%
def clean_text(text):
    text = text.replace('Pontos positivos', '').replace('\n', '').replace('\r', '')
    
    tokens = text.split()
    table = str.maketrans('', '', punctuation)
    tokens = [w.translate(table) for w in tokens if len(w) > 2]
    
    stop_words = stopwords.words('portuguese')
    stop_words.extend(['carro', 'bom', 'ótimo', 'boa', 'bem', 'excelente', 'otimo'])
    
    stop_words = set(stop_words)
    
    tokens = [unidecode.unidecode(stemmer.stem(w)) for w in tokens if not w in stop_words]
    
    
    return tokens

# %% [markdown]
# ### Fitando o modelo

# %%
transformer = CountVectorizer(analyzer=clean_text)
transformer.fit(ranking_complete['Texto Positivo'])
result = transformer.transform(ranking_complete['Texto Positivo'])

# %%
result_df = pd.DataFrame(result.todense(), columns= transformer.get_feature_names())

# %%
pd.DataFrame(result_df.sum()).sort_values(0, ascending=False)
# Out:
#                                    0
# confort                         1925
# espac                           1033
# motor                            954
# consum                           869
# dirigibil                        845
# econom                           808
# design                           803
# intern                           748
# segur                            701
# acab                             613
# estabil                          607
# dirig                            599
# estrad                           560
# manutenca                        504
# bonit                            446
# port                             445
# cust                             432
# baix                             411
# tod                              405
# mal                              379
# cidad                            371
# otim                             355
# desempenh                        332
# melhor                           324
# faz                              323
# veicul                           320
# cambi                            296
# benefici                         275
# tud                              271
# complet                          263
# ...                              ...
# 20012001                           1
# eleminh                            1
# elem                               1
# elegnc                             1
# elegi                              1
# eleganteconfortavelespacosoipv     1
# 2002                               1
# ele                                1
# elasticodesign                     1
# eh                                 1
# eguinica                           1
# eletricoconsum                     1
# eletricoslimp                      1
# eletrn                             1
# elogioest                          1
# embreagens                         1
# 20000km                            1
# embarcadaagilpotentesup            1
# embal                              1
# embac                              1
# eltricosmanuten                    1
# elog                               1
# eletrocromicoretrovisor            1
# elitet                             1
# elevadomelhor                      1
# elevadiss                          1
# eleum                              1
# eletronicocentral                  1
# 20011                              1
# gadolin                            1
#
# [6487 rows x 1 columns]

# %% [markdown]
# ### Aplicando LDA

# %%
ranking_complete['bag_words'] = ranking_complete['Texto Positivo'].apply(lambda x: clean_text(x))

# %%
dictionary = corpora.Dictionary(ranking_complete['bag_words'])
corpus = [dictionary.doc2bow(text) for text in ranking_complete['bag_words']]

# %%
NUM_TOPICS = 5
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=15)
#ldamodel.save('model5.gensim')
topics = ldamodel.print_topics(num_words=6)
for topic in topics:
    print(topic)
# Out:
# (0, '0.008*"econom" + 0.004*"fort" + 0.003*"barat" + 0.003*"veicul" + 0.003*"motor" + 0.003*"baix"')
# (1, '0.016*"design" + 0.015*"confort" + 0.013*"consum" + 0.012*"motor" + 0.012*"acab" + 0.011*"segur"')
# (2, '0.012*"confort" + 0.011*"design" + 0.006*"segur" + 0.005*"estabil" + 0.005*"espac" + 0.004*"motor"')
# (3, '0.034*"confort" + 0.020*"espac" + 0.016*"motor" + 0.015*"consum" + 0.015*"econom" + 0.014*"dirigibil"')
# (4, '0.028*"confort" + 0.018*"design" + 0.014*"motor" + 0.013*"dirigibil" + 0.012*"espac" + 0.011*"segur"')

# %%
#new_doc = prepare_text_for_lda(new_doc)
def get_group_lda(list_text):
    #new_doc = clean_text(list_text)
    new_doc_bow = dictionary.doc2bow(list_text)
    #print(new_doc_bow)
    result = ldamodel.get_document_topics(new_doc_bow)[0][0]
    
    return result

# %%
ranking_complete['Grupo'] = ranking_complete['bag_words'].apply(lambda x: get_group_lda(x))

# %%
ranking_complete[ranking_complete['Grupo'] == 4]
# Out:
#      Conforto / Acabamento  Consumo  Custo / Benefício  Design  \
# 14                     6.2      6.2                5.1     6.9
# 68                     7.6      7.6                7.6     8.7
# 85                     8.7      7.0                7.4     9.5
# 105                    9.5      7.5                9.0    10.0
# 108                    7.6      6.4                7.1     8.6
# 109                    8.7      8.3                8.0     9.4
# 111                    7.9      8.4                8.2     9.1
# 123                    9.8      7.8                8.8     7.8
# 144                    8.6      7.2                7.8     9.3
# 151                    8.7      6.3                7.8     9.4
# 165                    NaN      NaN                NaN     NaN
# 166                    7.7      7.7                9.3     9.0
# 174                    8.0      8.7                8.3     8.7
# 176                    9.4      7.4                8.7     9.6
# 184                    9.1      7.4                8.4     9.3
# 196                    9.3      7.7                8.0     9.3
# 210                    9.7      9.7                8.7     9.7
# 236                    9.2      7.3                8.4     9.2
# 246                    9.8      8.6                9.4     9.8
# 254                   10.0      8.7                9.7     9.7
# 274                    9.0      6.8                8.1     9.3
# 279                    9.3      7.6                9.2     9.6
# 290                    9.0      8.3                8.2     9.1
# 292                    8.9      8.1                8.7     9.7
# 299                    9.1      9.1                8.9     9.6
# 302                    9.2      8.4                9.5     9.7
# 307                    9.2      9.5                9.3     9.8
#
#      Dirigibilidade  Manutenção  Performance       Marca            Modelo  \
# 14              7.2         4.1          6.8        FIAT            DUCATO
# 68              8.4         6.7          8.0     PEUGEOT            206 SW
# 85              9.0         7.6          7.6     HYUNDAI               I30
# 105             9.5         9.0          9.0     CITROËN        C4 PICASSO
# 108             7.6         7.5          7.7     HYUNDAI              HB20
# 109             9.3         8.5          9.5   CHEVROLET           TRACKER
# 111             8.6         6.2          8.9         JAC                J2
# 123             9.6         7.8          9.2        FIAT             MAREA
# 144             9.1         7.1          8.3        FIAT              TORO
# 151             8.9         7.5          8.7  VOLKSWAGEN        NEW BEETLE
# 165             NaN         NaN          NaN  VOLKSWAGEN            PASSAT
# 166             9.0         7.7          6.7       LIFAN               X60
# 174             9.2         8.0          8.5        FORD  NEW FIESTA HATCH
# 176             9.5         7.7          9.4        FORD              EDGE
# 184             9.0         7.6          8.2        JEEP          RENEGADE
# 196             9.0         6.7          9.4     CITROËN            C4 VTR
# 210            10.0         8.3          9.7        AUDI                A3
# 236             9.3         8.4          9.1   CHEVROLET             SONIC
# 246             9.6         8.4         10.0     CITROËN         C4 LOUNGE
# 254            10.0         9.3          9.0     PEUGEOT              3008
# 274             9.5         8.5          8.4     CITROËN                C4
# 279             9.4         7.2          9.9        FORD            FUSION
# 290             9.2         8.0         10.0     PEUGEOT               308
# 292             9.1         8.7          9.2         JAC                T6
# 299             9.5         8.7          8.1      NISSAN             KICKS
# 302             9.7         8.7          8.8     PEUGEOT              2008
# 307             9.8         9.2          9.6        AUDI          A3 SEDAN
#
#       Ano  Pages     Price  ranking   Value  vendas_normalizada  Grupo
# 14   2018      3  108500.0      NaN   0.000            0.000000      4
# 68   2008      7   15518.0      NaN   0.000            0.000000      4
# 85   2016      7   70160.0      NaN   0.000            0.000000      4
# 105  2019      6  134990.0      NaN   0.000            0.000000      4
# 108  2019      7   43990.0      2.0  50.419            0.562586      4
# 109  2018      7   85890.0     26.0  13.440            0.149967      4
# 111  2016      5   42390.0      NaN   0.000            0.000000      4
# 123  2007      7   16050.0      NaN   0.000            0.000000      4
# 144  2019      6   90990.0      NaN   0.000            0.000000      4
# 151  2010      4   39175.0      NaN   0.000            0.000000      4
# 165  2018      4  178130.0      NaN   0.000            0.000000      4
# 166  2019      7   68990.0      NaN   0.000            0.000000      4
# 174  2018      7   56690.0      NaN   0.000            0.000000      4
# 176  2018      7  249800.0      NaN   0.000            0.000000      4
# 184  2018      7   69990.0     15.0  21.430            0.239121      4
# 196  2009      3   24611.0      NaN   0.000            0.000000      4
# 210  2018      7  128990.0      NaN   0.000            0.000000      4
# 236  2014      5   34020.0      NaN   0.000            0.000000      4
# 246  2019      7   88400.0      NaN   0.000            0.000000      4
# 254  2019      7  145990.0     69.0   1.605            0.017909      4
# 274  2014      6   35568.0      NaN   0.000            0.000000      4
# 279  2018      7  119900.0     61.0   2.145            0.023934      4
# 290  2019      7   69990.0      NaN   0.000            0.000000      4
# 292  2016      4   77990.0      NaN   0.000            0.000000      4
# 299  2019      7   73990.0     14.0  21.837            0.243662      4
# 302  2019      7   69990.0     45.0   4.229            0.047188      4
# 307  2018      5  118990.0      NaN   0.000            0.000000      4

# %%
ranking_complete[ranking_complete['Grupo'] == 0]
# Out:
#      Conforto / Acabamento  Consumo  Custo / Benefício  Design  \
# 24                     7.6      9.4                8.4     7.2
# 27                     8.5      7.5                6.5     9.5
# 30                     8.5      7.7                8.3     8.3
# 43                     6.1      6.2                7.1     7.0
# 56                     8.0      7.5                7.0     7.5
# 67                     7.9      8.3                8.2     8.0
# 92                     9.5      9.2                6.5     8.5
# 103                    7.8      8.1                7.7     9.0
# 147                    8.2      8.5                8.1     9.2
# 220                    8.1      8.7                8.6     9.1
# 251                    8.5      8.9                8.3     8.9
# 285                   10.0      9.0                9.8    10.0
# 305                    9.2      9.0                9.5     9.8
# 322                    9.3      8.9                9.6     9.8
#
#      Dirigibilidade  Manutenção  Performance       Marca      Modelo   Ano  \
# 24              7.8         6.4          7.7     PEUGEOT         106  2001
# 27              8.5         7.0          6.5         KIA        SOUL  2019
# 30              8.5         8.0          8.7        FORD       PAMPA  1997
# 43              7.2         6.9          7.3   CHEVROLET     CLASSIC  2016
# 56              9.0         7.0          7.5     TROLLER          T4  2018
# 67              8.6         8.3          8.1       CHERY        FACE  2015
# 92              9.8         6.5          9.2  LAND ROVER  FREELANDER  2015
# 103             8.5         6.9          7.8        SEAT       IBIZA  2002
# 147             8.7         8.1          8.0     CITROËN          C3  2019
# 220             9.3         8.4          9.1  VOLKSWAGEN        POLO  2019
# 251             8.8         8.3          8.8        FIAT        MOBI  2019
# 285            10.0         9.8          9.2     CITROËN          C5  2012
# 305             9.5         9.0          9.8         BMW          X1  2019
# 322             9.8         9.0          9.1         JAC          T5  2018
#
#      Pages     Price  ranking   Value  vendas_normalizada  Grupo
# 24       5    7331.0      NaN   0.000            0.000000      0
# 27       3   89990.0      NaN   0.000            0.000000      0
# 30       4   11941.0      NaN   0.000            0.000000      0
# 43       7   28914.0      NaN   0.000            0.000000      0
# 56       6  128994.0      NaN   0.000            0.000000      0
# 67       5   23605.0      NaN   0.000            0.000000      0
# 92       4  121437.0      NaN   0.000            0.000000      0
# 103      3    8827.0      NaN   0.000            0.000000      0
# 147      7   50390.0     47.0   3.639            0.040605      0
# 220      7   50490.0      4.0  34.138            0.380919      0
# 251      3   32590.0     12.0  24.997            0.278922      0
# 285      4   47281.0      NaN   0.000            0.000000      0
# 305      3  191950.0     62.0   1.995            0.022261      0
# 322      7   69990.0      NaN   0.000            0.000000      0

# %%
ranking_complete = ranking_complete.drop(['Texto Positivo', 'bag_words'], 1)

# %%
ranking_complete.to_csv('ranking_complete_group.csv', index=False)
